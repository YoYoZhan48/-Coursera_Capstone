# %% [markdown]
# # Where to Start A Coffee Shop in Toronto (Report)

# %% [markdown]
# ## Introduction

# %% [markdown]
# For people whoever want to start new coffee business in Toronto, one of the most important things they need to know is: which neighbour in Toronto is a good place to start. An ideal neighhour should has a larger coffee demand with fewer competitors. And the ideal neighbour that will be released the end of this report, satisfies those requirement: the neighbour closes to a university and has a large number of shops (which means that people in this region have some degree of purchase power). The region has only one coffee shop which hasn't been rated yet (which means that the shop is either recently opened or unpopular). There is no doublt that starting a coffee shop in such neighbour will be much easier.

# %% [markdown]
# ## Data

# %% [markdown]
# The data used in this report have three components:
# 1. Data of neighbourhood names that will be obtained from a wikipedia page;
# 2. Lattitude and logitude info of those neighbourhoods that are contained in an excel file;
# 3. Venue info that will be extracted via FourSquare API

# %% [markdown]
# ## Methodology & Results

# %% [markdown]
# The first thing to do is to obtain neighbourhood information from Wikipedia. The data obtained include: Postal Code, Borough, and Neighbourhood.

# %% [markdown]
# ![Screen%20Shot%202019-05-19%20at%2000.21.39.png](attachment:Screen%20Shot%202019-05-19%20at%2000.21.39.png)

# %% [markdown]
# Particularly, the postal code info of those neighbourhoods are find the lattitude and logitude of those neighbours from the excel file.

# %% [markdown]
# ![Screen%20Shot%202019-05-19%20at%2000.26.04.png](attachment:Screen%20Shot%202019-05-19%20at%2000.26.04.png)

# %% [markdown]
# With the cordinate info of those neighbourhoods, we extrated the venues info of each neighbourhood via FourSquare API.

# %% [markdown]
# ![Screen%20Shot%202019-05-19%20at%2000.27.44.png](attachment:Screen%20Shot%202019-05-19%20at%2000.27.44.png)

# %% [markdown]
# We ran analysis of coffee shop within each neighbourhood. The neighbourhood with less than 3 coffee shops and no coffee giants such as Starbucks are selected.

# %% [markdown]
# ![Screen%20Shot%202019-05-19%20at%2000.30.36.png](attachment:Screen%20Shot%202019-05-19%20at%2000.30.36.png)

# %% [markdown]
# Here we have 10 neighbourhoods that satisfy our requirements. To determine which neighbourhood to start coffee business, we also exam the number of venues of these 10 neighbourhoods. Harbord,University of Toronto has the largest number of venues, becoming our idea place to start coffee business.

# %% [markdown]
# ![Screen%20Shot%202019-05-19%20at%2000.33.29.png](attachment:Screen%20Shot%202019-05-19%20at%2000.33.29.png)

# %% [markdown]
# ## Conclusion & Discussion

# %% [markdown]
# Based on the above analysis, we think Harbord,University of Toronto is an ideal place to start coffee business.
